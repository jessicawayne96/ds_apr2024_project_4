# %%
 # Import the required modules
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold

# Metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve, RocCurveDisplay

# Pre-Processing
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# The path to the CSV file
filepath = "Resources/fictional_character_battles_complex.csv"

#reading the csv file
battle_info = pd.read_csv(filepath)

print(battle_info.shape)
battle_info.head(15)
# Out:
# (2351, 8)
#        Character   Universe  Strength  Speed  Intelligence SpecialAbilities  \
# 0   Wonder Woman     Marvel         7      8             3      Telekinesis
# 1       Iron Man     Marvel         4      7             9      Telekinesis
# 2       Iron Man  DC Comics         8      7             5      Telekinesis
# 3     Spider-Man  DC Comics         5      6            10      Telekinesis
# 4          Flash     Marvel         7      6             2     Invisibility
# 5     Spider-Man  DC Comics        10      9             7     Invisibility
# 6   Wonder Woman     Marvel         3      6             2   Super Strength
# 7           Thor  DC Comics         7      2             4     Invisibility
# 8         Batman  DC Comics         8      2             7           Flight
# 9       Iron Man  DC Comics         5      5             4           Flight
# 10      Superman  DC Comics         4      4             7      Telekinesis
# 11          Thor  DC Comics         8      2             7           Flight
# 12      Iron Man  DC Comics         8      3             1   Super Strength
# 13        Batman     Marvel         3      7             6     Invisibility
# 14         Flash  DC Comics         6      8             9     Invisibility
#
#       Weaknesses  BattleOutcome
# 0     Kryptonite              0
# 1     Kryptonite              0
# 2          Magic              0
# 3     Kryptonite              0
# 4          Magic              0
# 5   Wooden Stake              1
# 6         Silver              1
# 7          Magic              1
# 8         Silver              0
# 9   Wooden Stake              0
# 10    Kryptonite              0
# 11  Wooden Stake              0
# 12        Silver              0
# 13  Wooden Stake              0
# 14    Kryptonite              0

# %%
battle_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2351 entries, 0 to 2350
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Character         2351 non-null   object
#  1   Universe          2351 non-null   object
#  2   Strength          2351 non-null   int64
#  3   Speed             2351 non-null   int64
#  4   Intelligence      2351 non-null   int64
#  5   SpecialAbilities  2351 non-null   object
#  6   Weaknesses        2351 non-null   object
#  7   BattleOutcome     2351 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 147.1+ KB

# %%
battle_info.nunique()
# Out:
# Character            8
# Universe             2
# Strength            10
# Speed               10
# Intelligence        10
# SpecialAbilities     4
# Weaknesses           4
# BattleOutcome        2
# dtype: int64

# %%
# we talked about making a new column to make the characters have the correct universe
# making a copy of the data frame to see what the data would look like 
battle_info2 = battle_info.copy()

# %%
#dropping the old universe column
battle_info2 = battle_info2.drop(['Universe'], axis =1)
battle_info2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2351 entries, 0 to 2350
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Character         2351 non-null   object
#  1   Strength          2351 non-null   int64
#  2   Speed             2351 non-null   int64
#  3   Intelligence      2351 non-null   int64
#  4   SpecialAbilities  2351 non-null   object
#  5   Weaknesses        2351 non-null   object
#  6   BattleOutcome     2351 non-null   int64
# dtypes: int64(4), object(3)
# memory usage: 128.7+ KB

# %%
#making a list of the values in the character column to make sure i dont miss anyone
battle_info2['Character'].unique()
# Out:
# array(['Wonder Woman', 'Iron Man', 'Spider-Man', 'Flash', 'Thor',
#        'Batman', 'Superman', 'Captain America'], dtype=object)

# %%
#making list of character names to make it eaiser
marvel_characters = ['Iron Man','Spider-Man','Thor','Captain America']
dc_characters = ['Wonder Woman','Flash','Batman','Superman']

# %%
# Creating a NEW universe column based on the condition for the correct character universe
battle_info2['Universe'] = battle_info2['Character'].apply(lambda x: 'Marvel' if x in marvel_characters else 'DC Comics')
battle_info2.head(25)
# Out:
#           Character  Strength  Speed  Intelligence SpecialAbilities  \
# 0      Wonder Woman         7      8             3      Telekinesis
# 1          Iron Man         4      7             9      Telekinesis
# 2          Iron Man         8      7             5      Telekinesis
# 3        Spider-Man         5      6            10      Telekinesis
# 4             Flash         7      6             2     Invisibility
# 5        Spider-Man        10      9             7     Invisibility
# 6      Wonder Woman         3      6             2   Super Strength
# 7              Thor         7      2             4     Invisibility
# 8            Batman         8      2             7           Flight
# 9          Iron Man         5      5             4           Flight
# 10         Superman         4      4             7      Telekinesis
# 11             Thor         8      2             7           Flight
# 12         Iron Man         8      3             1   Super Strength
# 13           Batman         3      7             6     Invisibility
# 14            Flash         6      8             9     Invisibility
# 15         Superman         5      6             2     Invisibility
# 16         Iron Man         2      5             3           Flight
# 17  Captain America         8      1            10     Invisibility
# 18     Wonder Woman         6      8             5      Telekinesis
# 19             Thor         2      3             9      Telekinesis
# 20     Wonder Woman         5      6             4      Telekinesis
# 21       Spider-Man         1      3             1           Flight
# 22         Iron Man        10      7             4     Invisibility
# 23         Superman         6      7             6           Flight
# 24         Superman         9      9             5     Invisibility
#
#       Weaknesses  BattleOutcome   Universe
# 0     Kryptonite              0  DC Comics
# 1     Kryptonite              0     Marvel
# 2          Magic              0     Marvel
# 3     Kryptonite              0     Marvel
# 4          Magic              0  DC Comics
# 5   Wooden Stake              1     Marvel
# 6         Silver              1  DC Comics
# 7          Magic              1     Marvel
# 8         Silver              0  DC Comics
# 9   Wooden Stake              0     Marvel
# 10    Kryptonite              0  DC Comics
# 11  Wooden Stake              0     Marvel
# 12        Silver              0     Marvel
# 13  Wooden Stake              0  DC Comics
# 14    Kryptonite              0  DC Comics
# 15  Wooden Stake              0  DC Comics
# 16    Kryptonite              0     Marvel
# 17         Magic              1     Marvel
# 18        Silver              1  DC Comics
# 19    Kryptonite              0     Marvel
# 20    Kryptonite              0  DC Comics
# 21  Wooden Stake              0     Marvel
# 22         Magic              1     Marvel
# 23    Kryptonite              0  DC Comics
# 24         Magic              0  DC Comics

# %%
# data is clean, will leave the encoding and feature engineering for the ML notebook
#saving as a new csv to load into the ML notebook
battle_info2.to_csv('clean_battle_info.csv', index=False)
